# %% [markdown]
# # Notebook 05 - Relatório Final (EDA)
# Objetivo: consolidar análises e visualizações de negócio a partir do dataset final de suplementos.
# ---

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style="whitegrid", palette="muted", font_scale=1.1)

df = pd.read_csv("../data/DT_Store_Suplements_final.csv")
df["Receita"] = df["Preco"] * df["Quantidade"]

# %% [markdown]
# ## 🔹 Receita Total

# %%
receita_total = df["Receita"].sum()
print(f"Receita total: R$ {receita_total:,.2f}")
# Out:
# Receita total: R$ 244,622.95

# %% [markdown]
# 👉 **Receita Total:** O faturamento total no período analisado foi de **R$ XXX.XXX,XX**.

# %% [markdown]
# ## 🔹 Top 5 Produtos mais Vendidos (Quantidade)

# %%
top_produtos_qtd = df.groupby("Produto")["Quantidade"].sum().sort_values(ascending=False).head(5)

plt.figure(figsize=(8,5))
sns.barplot(x=top_produtos_qtd.values, y=top_produtos_qtd.index, palette="Blues_r")
plt.title("Top 5 Produtos mais Vendidos (Quantidade)")
plt.xlabel("Quantidade Vendida")
plt.ylabel("Produto")
plt.show()
# Out:
# C:\Users\vanma\AppData\Local\Temp\ipykernel_17364\858906186.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_produtos_qtd.values, y=top_produtos_qtd.index, palette="Blues_r")

# %% [markdown]
# 👉 O produto mais vendido em quantidade foi **XYZ**, seguido por **ABC**.

# %% [markdown]
# ## 🔹 Top 5 Produtos por Receita

# %%
top_produtos_receita = df.groupby("Produto")["Receita"].sum().sort_values(ascending=False).head(5)

plt.figure(figsize=(8,5))
sns.barplot(x=top_produtos_receita.values, y=top_produtos_receita.index, palette="Greens_r")
plt.title("Top 5 Produtos por Receita")
plt.xlabel("Receita (R$)")
plt.ylabel("Produto")
plt.show()
# Out:
# C:\Users\vanma\AppData\Local\Temp\ipykernel_17364\1313472524.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_produtos_receita.values, y=top_produtos_receita.index, palette="Greens_r")

# %% [markdown]
# 👉 Em faturamento, o destaque foi o **XYZ**, responsável por grande parte da receita.

# %% [markdown]
# ## 🔹 Marcas que mais faturam

# %%
top_marcas_receita = df.groupby("Marca")["Receita"].sum().sort_values(ascending=False).head(5)

plt.figure(figsize=(8,5))
sns.barplot(x=top_marcas_receita.values, y=top_marcas_receita.index, palette="Oranges_r")
plt.title("Top Marcas por Receita")
plt.xlabel("Receita (R$)")
plt.ylabel("Marca")
plt.show()
# Out:
# C:\Users\vanma\AppData\Local\Temp\ipykernel_17364\3167210767.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_marcas_receita.values, y=top_marcas_receita.index, palette="Oranges_r")

# %% [markdown]
# 👉 A marca **AAA** foi a que mais faturou, mostrando forte presença no mercado.

# %% [markdown]
# ## 🔹 Distribuição de Formas de Pagamento

# %%
plt.figure(figsize=(6,6))
df["Pagamento"].value_counts().plot.pie(
    autopct="%.1f%%", startangle=90, colors=sns.color_palette("pastel")
)
plt.title("Distribuição de Formas de Pagamento")
plt.ylabel("")
plt.show()

# %% [markdown]
# 👉 Observa-se que **Cartão** é a forma de pagamento mais usada, seguido de **PIX**.

# %% [markdown]
# ## 🔹 Comparação entre Lojas

# %%
lojas_receita = df.groupby("Loja")["Receita"].sum()

plt.figure(figsize=(7,5))
sns.barplot(x=lojas_receita.index, y=lojas_receita.values, palette="Purples_r")
plt.title("Receita por Loja")
plt.xlabel("Loja")
plt.ylabel("Receita (R$)")
plt.show()
# Out:
# C:\Users\vanma\AppData\Local\Temp\ipykernel_17364\3110603225.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=lojas_receita.index, y=lojas_receita.values, palette="Purples_r")

# %% [markdown]
# 👉 A **Loja X** apresentou o maior faturamento, enquanto a **Loja Y** teve desempenho inferior.

# %% [markdown]
# # ✅ Conclusão
# A análise exploratória mostra os principais indicadores de desempenho:
# - Produtos e marcas líderes em vendas e receita
# - Preferências de pagamento dos clientes
# - Comparação clara entre lojas
#
# Essas informações podem embasar decisões estratégicas em marketing, estoque e expansão.
